# %%
import pandas as pd
import seaborn as sns
import numpy as np
from collections import defaultdict
import math
import matplotlib.pyplot as plt
import functions as fn

# %%
# gene_physical_pairwise_interactions contains a set of sorted 2-tuples
gene_physical_pairwise_interactions = fn.get_gene_physical_interactions()
print(len(gene_physical_pairwise_interactions))
# Out:
# 79774

# %%
db_interactions[db_interactions.standard_gene_name_hit.str.contains("brx1", case=False)]
# Out:
#        feature_name_bait standard_gene_name_bait feature_name_hit  \
# 5391             YBL003C                    HTA2          YOL077C
# 11544            YBR010W                    HHT1          YOL077C
# 14100            YBR081C                    SPT7          YOL077C
# 22248            YBR278W                    DPB3          YOL077C
# 26501            YCR057C                    PWP2          YOL077C
# ...                  ...                     ...              ...
# 122618           YPL259C                    APM1          YOL077C
# 122619           YPR010C                  RPA135          YOL077C
# 122620           YPR016C                    TIF6          YOL077C
# 122623           YPR143W                   RRP15          YOL077C
# 122624           YPR161C                    SGV1          YOL077C
#
#        standard_gene_name_hit      experiment_type  \
# 5391                     BRX1  Affinity Capture-MS
# 11544                    BRX1  Affinity Capture-MS
# ...

# %%
db_dir = "/Users/bjarnold/Princeton_DataX/Epistasis/higher_order_reanalysis/yeast_screens/database/BIOGRID"
db_interactions_biogrid = pd.read_csv(f"{db_dir}/BIOGRID-ORGANISM-Saccharomyces_cerevisiae_S288c-4.4.211.tab3.txt", sep="\t")
db_interactions_biogrid = db_interactions_biogrid[['Official Symbol Interactor A', 'Official Symbol Interactor B', 'Experimental System Type']]
db_interactions_biogrid = db_interactions_biogrid.rename(columns={'Official Symbol Interactor A':'official_symbol_interactor_a',
                                'Official Symbol Interactor B':'official_symbol_interactor_b',
                                'Experimental System Type':'experimental_system_type'})
db_interactions_biogrid.head()
# Out:
# /Users/bjarnold/miniconda/envs/datascience/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (1,2,18) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-737b00f92e10> in <module>
#       2 db_interactions_biogrid = pd.read_csv(f"{db_dir}/BIOGRID-ORGANISM-Saccharomyces_cerevisiae_S288c-4.4.211.tab3.txt", sep="\t")
#       3 db_interactions_biogrid = db_interactions_biogrid[['Official Symbol Interactor A', 'Official Symbol Interactor B', 'Experimental System Type']]
# ----> 4 db_interactions_biogrid = db_interactions.rename(columns={'Official Symbol Interactor A':'official_symbol_interactor_a',
# ...

# %%
#db_interactions_biogrid['Experimental System'].unique()
len(db_interactions_biogrid[db_interactions_biogrid['Experimental System Type'] == "physical"])
# Out:
# 200676
